# %% [markdown]
# # Set admin percentage
#
# Run the LlamaLend v2 admin-percentage vote simulation. Environment variables are loaded from the repository's `.env` file.

# %%
# %load_ext dotenv
# %dotenv -o .env

# %run ../scripts/llamalend-v2/set_admin_percentage.py
# Out:
# Metadata
# [Optimism] Increase the admin fee percentage from 1% to 10% on three LlamaLend v2 markets via the Configurator (0xd36c590531cAF5F620C57Faf5827Ce8E7f6E5Bec): wstETH/WETH (0x745422BF49f3F6e4A8E12E4abD19339E7910F8C9); WBTC/USDC (0x9fC15ac3EF97093832f49B7997A58E29b49C56dE); wstETH/USDC (0xb5EC7A3D591877A66BE4f3eafdC4205E98A1BCAA).
#
# Calldata
# Call via agent (0x40907540d8a6C65c637785e8f8B742ae6b0b9968):
#  ├─ To: 0x8e1e5001C7B8920196c7E3EdF2BCf47B2B6153ff
#  ├─ Function: broadcast
# ...
