# %% [markdown]
# # Optimize Tricrypto2 Parameters
#
# Run the Tricrypto2 parameter update vote simulation. Environment variables are loaded from the repository's `.env` file.

# %%
# %load_ext dotenv
# %dotenv -o .env

# %run ../scripts/tricrypto/update_parameters.py
# Out:
# Metadata
# Optimize pool parameters for Tricrypto2 (0xd51a44d3fae010294c616388b506acda1bfaae46) and ramp A and gamma over 14 days.
#
# Calldata
# Call via agent (0x4eeb3ba4f221ca16ed4a0cc7254e2e32df948c5f):
#  ├─ To: 0x7a1f2f99B65f6c3B2413648c86C0326CfF8D8837
#  ├─ Function: commit_new_parameters
#  └─ Inputs: [('address', '_pool', '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46'), ('uint256', '_new_mid_fee', '330000'), ('uint256', '_new_out_fee', '726300000'), ('uint256', '_new_admin_fee', '5000000000'), ('uint256', '_new_fee_gamma', '116255000000000000'), ('uint256', '_new_allowed_extra_profit', '440000000000'), ('uint256', '_new_adjustment_step', '24500000000000'), ('uint256', '_new_ma_half_time', '600')]
#
# Call via agent (0x4eeb3ba4f221ca16ed4a0cc7254e2e32df948c5f):
#  ├─ To: 0x7a1f2f99B65f6c3B2413648c86C0326CfF8D8837
#  ├─ Function: ramp_A_gamma
# ...
